# %% [markdown]
# **Quora Question Pairs**
#
# Where else but Quora can a physicist help a chef with a math problem and get cooking tips in return? Quora is a place to gain and share knowledge—about anything. It’s a platform to ask questions and connect with people who contribute unique insights and quality answers. This empowers people to learn from each other and to better understand the world.
#
# Over 100 million people visit Quora every month, so it's no surprise that many people ask similarly worded questions. Multiple questions with the same intent can cause seekers to spend more time finding the best answer to their question, and make writers feel they need to answer multiple versions of the same question. Quora values canonical questions because they provide a better experience to active seekers and writers, and offer more value to both of these groups in the long term.
#
# Currently, Quora uses a Random Forest model to identify duplicate questions. In this competition, Kagglers are challenged to tackle this natural language processing problem by applying advanced techniques to classify whether question pairs are duplicates or not. Doing so will make it easier to find high quality answers to questions resulting in an improved experience for Quora writers, seekers, and readers.
#
# Acknowledgements: Data and descriptions modified from https://www.kaggle.com/c/quora-question-pairs

# %%
import numpy as np
import pandas as pd
import sklearn as sl

# %%
# import datasets
df_train = pd.read_csv('data/train_data.csv')
df_test = pd.read_csv('data/test_data.csv')
train_label = pd.read_csv('data/train_labels.csv')

# %%
df_train = df_train.drop('is_duplicate',1)
df_train = df_train.merge(train_label,on="id")

# %%
df_train
# Out:
#             id                                          question1  \
# 0            0  What is the step by step guide to invest in sh...
# 1            1  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2            2  How can I increase the speed of my internet co...
# 3            3  Why am I mentally very lonely? How can I solve...
# 4            4  Which one dissolve in water quikly sugar, salt...
# 5            5  Astrology: I am a Capricorn Sun Cap moon and c...
# 6            6                                Should I buy tiago?
# 7            7                     How can I be a good geologist?
# 8            8                    When do you use シ instead of し?
# 9            9  Motorola (company): Can I hack my Charter Moto...
# 10          10  Method to find separation of slits using fresn...
# 11          11        How do I read and find my YouTube comments?
# 12          12               What can make Physics easy to learn?
# 13          13        What was your first sexual experience like?
# 14          14  What are the laws to change your status from a...
# 15          16                       What does manipulation mean?
# 16          17  Why do girls want to be friends with the guy t...
# 17          18  Why are so many Quora users posting questions ...
# 18          19  Which is the best digital marketing institutio...
# 19          22    What are the questions should not ask on Quora?
# 20          24  What does it mean that every time I look at th...
# 21          25  What are some tips on making it through the jo...
# 22          26                           What is web application?
# 23          27  Does society place too much importance on sports?
# 24          28             What is best way to make money online?
# 25          29             How should I prepare for CA final law?
# 26          30      What's one thing you would like to do better?
# 27          31  What are some special cares for someone with a...
# 28          32  What Game of Thrones villain would be the most...
# 29          33  Does the United States government still blackl...
# ...        ...                                                ...
# 323134  404253             How do I make website like fmovies.to?
# 323135  404255                 Does IBM Watson use ElasticSearch?
# 323136  404256  What are some of the most common questions ask...
# 323137  404257             What is Bitcoin? Is it legal in India?
# 323138  404258  What is the difference between a psychologist ...
# 323139  404259  What do you think is wrong with Indian schools...
# 323140  404260                   Which phone is best under 12000?
# 323141  404261  Who is the overall most popular Game of Throne...
# 323142  404262          How do you troubleshoot a Toshiba laptop?
# 323143  404266  What is the green dot next to the phone icon o...
# 323144  404267  What are the causes of the fall of the Roman E...
# 323145  404268  Why don't we still do great music like in the ...
# 323146  404271  Does Stalin have any grandchildren that are st...
# 323147  404272  What are the best new car products or inventio...
# 323148  404273    What happens if you put milk in a coffee maker?
# 323149  404274  Will the next generation of parenting change o...
# 323150  404275  In accounting, why do we debit expenses and cr...
# 323151  404276                         What is copilotsearch.com?
# 323152  404277                            What does analytics do?
# 323153  404279  What is the minimum time required to build a f...
# 323154  404280  What are some outfit ideas to wear to a frat p...
# 323155  404281  Why is Manaphy childish in Pokémon Ranger and ...
# 323156  404282        How does a long distance relationship work?
# 323157  404283  What do you think of the removal of the MagSaf...
# 323158  404284         What does Jainism say about homosexuality?
# 323159  404285  How many keywords are there in the Racket prog...
# 323160  404286          Do you believe there is life after death?
# 323161  404287                                  What is one coin?
# 323162  404288  What is the approx annual cost of living while...
# 323163  404289              What is like to have sex with cousin?
#
#                                                 question2  is_duplicate
# 0       What is the step by step guide to invest in sh...             0
# 1       What would happen if the Indian government sto...             0
# 2       How can Internet speed be increased by hacking...             0
# 3       Find the remainder when [math]23^{24}[/math] i...             0
# 4                 Which fish would survive in salt water?             0
# 5       I'm a triple Capricorn (Sun, Moon and ascendan...             1
# 6       What keeps childern active and far from phone ...             0
# 7               What should I do to be a great geologist?             1
# 8                   When do you use "&" instead of "and"?             0
# 9       How do I hack Motorola DCX3400 for free internet?             0
# 10      What are some of the things technicians can te...             0
# 11                 How can I see all my Youtube comments?             1
# 12                How can you make physics easy to learn?             1
# 13                 What was your first sexual experience?             1
# 14      What are the laws to change your status from a...             0
# 15                          What does manipulation means?             1
# 16               How do guys feel after rejecting a girl?             0
# 17      Why do people ask Quora questions which can be...             1
# 18      Which is the best digital marketing institute ...             0
# 19                  Which question should I ask on Quora?             0
# 20       How many times a day do a clock’s hands overlap?             0
# 21      What are some tips on making it through the jo...             0
# 22                 What is the web application framework?             0
# 23               How do sports contribute to the society?             0
# 24              What is best way to ask for money online?             0
# 25      How one should know that he/she completely pre...             1
# 26        What's one thing you do despite knowing better?             0
# 27      How can I keep my nose from getting stuffy at ...             1
# 28      What Game of Thrones villain would you most li...             1
# 29      How is the average speed of gas molecules dete...             0
# ...                                                   ...           ...
# 323134          Which is the best way to make my website?             0
# 323135                     Does Google use Elasticsearch?             0
# 323136  What are the most common questions asked in in...             0
# 323137                         Is Bitcoin legal in India?             1
# 323138  What is the difference between psychologist an...             1
# 323139   What is wrong with the current indian education?             1
# 323140           What is the best phone to buy below 15k?             0
# 323141  Who is the most popular character in the Game ...             1
# 323142                   How do I reset a Toshiba laptop?             0
# 323143  My boyfriend says he deleted his Facebook Mess...             0
# 323144  What were the most important causes and effect...             1
# 323145       Should I raise my young child on 80's music?             0
# 323146  What was Joseph Stalin's 5 year plan? How did ...             0
# 323147  What are some mind-blowing vehicles tools that...             1
# 323148  What would happen if I put milk instead of wat...             1
# 323149  What kind of parents will the next generation ...             1
# 323150  What is a utilities expense in accounting? How...             0
# 323151                           What is ContenVania.com?             0
# 323152                   What are analytical people like?             0
# 323153  What is a cheaper and quicker way to build an ...             0
# 323154  What are some outfit ideas wear to a frat them...             1
# 323155  Why is Manaphy annoying in Pokemon ranger and ...             1
# 323156    How are long distance relationships maintained?             1
# 323157  What will the CPU upgrade to the 2016 Apple Ma...             0
# 323158  What does Jainism say about Gays and Homosexua...             1
# 323159  How many keywords are there in PERL Programmin...             0
# 323160         Is it true that there is life after death?             1
# 323161                                  What's this coin?             0
# 323162  I am having little hairfall problem but I want...             0
# 323163      What is it like to have sex with your cousin?             0
#
# [323164 rows x 4 columns]
